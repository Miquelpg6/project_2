# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
#Match results function

def results(base_url, team_to_find):
    results_list = []
    
    # Round from 1 to 26
    for jornada in range(1, 27):
        url = f"{base_url}{jornada}"
        
        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'lxml')

        # Search the result for the desired team
        result = None

        matches = soup.find_all('table', class_='uppercase w-100 fs-12_tp fs-11_ml table_resultats')  

        for match in matches:
            
            team1 = match.find('td', {"class": 'p-5 resultats-w-equip tr'}).text.strip()  
            team2 = match.find('td', {"class": 'p-5 resultats-w-equip tl'}).text.strip()  
            score = match.find('td', {"class": 'p-5 resultats-w-resultat tc'}).text.strip().replace("ACTA TANCADA", "")  

            # Verify if team is in the results
            if team_to_find in team1 or team_to_find in team2:
                result = f"{team1} {score} {team2}"
                break  

        if result:
            results_list.append(f"{result}")
        else:
            results_list.append(f"SD ESPANYOL B no se encontró en los resultados de la jornada {jornada}")
    
    return results_list

# %%
# Aplaying the function

base_url = "https://www.fcf.cat/resultats/2223/futbol-sala/lliga-primera-divisio-catalana-futbol-sala/bcn-gr-2/jornada-"
team_to_find = "SD ESPANYOL B"

results_list = results(base_url, team_to_find)

results_list
# Out:
# ['SD ESPANYOL B \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n0 - 5 C.E.DMS  A',
#  'FUNDACIÓ FUTBOL BADALONA A \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n4 - 8 SD ESPANYOL B',
#  'SD ESPANYOL B \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n1 - 1 AELIS-SAGE PARTNER EIXAMPLE B',
#  'FUTSAL CLASSIC BARCELONA, CLUB ESPORTIU  A \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n3 - 5 SD ESPANYOL B',
#  'SD ESPANYOL B \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n7 - 3 SANT ANDREU SAGRERA - AESA A',
#  'PLAY FUTSAL A \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n6 - 4 SD ESPANYOL B',
#  'SD ESPANYOL B \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n5 - 6 ALZINA ASSOC. ESP. A',
#  'MONTSENY CECD A \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n2 - 5 SD ESPANYOL B',
#  'SD ESPANYOL B \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n0 - 3 MAGIC SANTS FUTSAL B',
#  'F.S  BOSCO ROCAFORT A \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n7 - 4 SD ESPANYOL B',
#  'SD ESPANYOL B \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n0 - 4 FUTSAL ROSARIO CENTRAL A',
#  'BADALONA FUTSAL IRIS A \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n5 - 2 SD ESPANYOL B',
#  'LES CORTS ESPORTIU FUTSAL B \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n2 - 6 SD ESPANYOL B',
#  'C.E.DMS  A \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n6 - 6 SD ESPANYOL B',
#  'SD ESPANYOL B \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n4 - 3 FUNDACIÓ FUTBOL BADALONA A',
#  'AELIS-SAGE PARTNER EIXAMPLE B \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n4 - 6 SD ESPANYOL B',
#  'SD ESPANYOL B \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n9 - 3 FUTSAL CLASSIC BARCELONA, CLUB ESPORTIU  A',
#  'SANT ANDREU SAGRERA - AESA A \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n5 - 3 SD ESPANYOL B',
#  'SD ESPANYOL B \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n7 - 7 PLAY FUTSAL A',
#  'ALZINA ASSOC. ESP. A \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n7 - 5 SD ESPANYOL B',
#  'SD ESPANYOL B \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n9 - 5 MONTSENY CECD A',
#  'MAGIC SANTS FUTSAL B \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n3 - 5 SD ESPANYOL B',
#  'SD ESPANYOL B \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n3 - 4 F.S  BOSCO ROCAFORT A',
#  'FUTSAL ROSARIO CENTRAL A \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n1 - 3 SD ESPANYOL B',
#  'SD ESPANYOL B \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n4 - 7 BADALONA FUTSAL IRIS A',
#  'SD ESPANYOL B \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n2 - 1 LES CORTS ESPORTIU FUTSAL B']

# %%
# Function to clean all results 

def clean_results(results_list):
    cleaned_list = [item.replace('\n', '').replace('\t', '') for item in results_list]
    return cleaned_list

# %%
# Results clean

results_clean = clean_results(results_list)
results_clean
# Out:
# ['SD ESPANYOL B 0 - 5 C.E.DMS  A',
#  'FUNDACIÓ FUTBOL BADALONA A 4 - 8 SD ESPANYOL B',
#  'SD ESPANYOL B 1 - 1 AELIS-SAGE PARTNER EIXAMPLE B',
#  'FUTSAL CLASSIC BARCELONA, CLUB ESPORTIU  A 3 - 5 SD ESPANYOL B',
#  'SD ESPANYOL B 7 - 3 SANT ANDREU SAGRERA - AESA A',
#  'PLAY FUTSAL A 6 - 4 SD ESPANYOL B',
#  'SD ESPANYOL B 5 - 6 ALZINA ASSOC. ESP. A',
#  'MONTSENY CECD A 2 - 5 SD ESPANYOL B',
#  'SD ESPANYOL B 0 - 3 MAGIC SANTS FUTSAL B',
#  'F.S  BOSCO ROCAFORT A 7 - 4 SD ESPANYOL B',
#  'SD ESPANYOL B 0 - 4 FUTSAL ROSARIO CENTRAL A',
#  'BADALONA FUTSAL IRIS A 5 - 2 SD ESPANYOL B',
#  'LES CORTS ESPORTIU FUTSAL B 2 - 6 SD ESPANYOL B',
#  'C.E.DMS  A 6 - 6 SD ESPANYOL B',
#  'SD ESPANYOL B 4 - 3 FUNDACIÓ FUTBOL BADALONA A',
#  'AELIS-SAGE PARTNER EIXAMPLE B 4 - 6 SD ESPANYOL B',
#  'SD ESPANYOL B 9 - 3 FUTSAL CLASSIC BARCELONA, CLUB ESPORTIU  A',
#  'SANT ANDREU SAGRERA - AESA A 5 - 3 SD ESPANYOL B',
#  'SD ESPANYOL B 7 - 7 PLAY FUTSAL A',
#  'ALZINA ASSOC. ESP. A 7 - 5 SD ESPANYOL B',
#  'SD ESPANYOL B 9 - 5 MONTSENY CECD A',
#  'MAGIC SANTS FUTSAL B 3 - 5 SD ESPANYOL B',
#  'SD ESPANYOL B 3 - 4 F.S  BOSCO ROCAFORT A',
#  'FUTSAL ROSARIO CENTRAL A 1 - 3 SD ESPANYOL B',
#  'SD ESPANYOL B 4 - 7 BADALONA FUTSAL IRIS A',
#  'SD ESPANYOL B 2 - 1 LES CORTS ESPORTIU FUTSAL B']

# %%
# Function for the Round and Date


def jornada(url):
    # Send an HTTP GET request to the URL
    response = requests.get(url)

    soup = BeautifulSoup(response.text, 'lxml')

    # Find all ROUND and DATES by inspecting the page's HTML structure
    jornadas_and_dates = []

    jornada_elements = soup.find_all('th', {'colspan': '4'})
    date_elements = soup.find_all('th', {'colspan': '3'})

    # Iterate through the elements and collect the information
    for jornada, date in zip(jornada_elements, date_elements):
        jornada_text = jornada.text.strip()
        date_text = date.text.strip()
        jornadas_and_dates.append((jornada_text, date_text))
        
    return jornadas_and_dates

# %%
# Aplying the function

url = "https://www.fcf.cat/calendari/2223/futbol-sala/lliga-primera-divisio-catalana-futbol-sala/bcn-gr-2"
jornadas = jornada (url)
jornadas
# Out:
# [('Jornada 1', '15-10-2022'),
#  ('Jornada 2', '22-10-2022'),
#  ('Jornada 3', '29-10-2022'),
#  ('Jornada 4', '05-11-2022'),
#  ('Jornada 5', '12-11-2022'),
#  ('Jornada 6', '19-11-2022'),
#  ('Jornada 7', '26-11-2022'),
#  ('Jornada 8', '03-12-2022'),
#  ('Jornada 9', '17-12-2022'),
#  ('Jornada 10', '14-01-2023'),
#  ('Jornada 11', '21-01-2023'),
#  ('Jornada 12', '04-02-2023'),
#  ('Jornada 13', '11-02-2023'),
#  ('Jornada 14', '25-02-2023'),
#  ('Jornada 15', '04-03-2023'),
#  ('Jornada 16', '11-03-2023'),
#  ('Jornada 17', '18-03-2023'),
#  ('Jornada 18', '25-03-2023'),
#  ('Jornada 19', '01-04-2023'),
#  ('Jornada 20', '15-04-2023'),
#  ('Jornada 21', '22-04-2023'),
#  ('Jornada 22', '29-04-2023'),
#  ('Jornada 23', '06-05-2023'),
#  ('Jornada 24', '13-05-2023'),
#  ('Jornada 25', '20-05-2023'),
#  ('Jornada 26', '27-05-2023')]

# %%
# funciton to clean ROUNDS

def clean_jornadas (jornadas):
    jornadas_final = [str(item).strip('()') for item in jornadas]
    return jornadas_final

# %%
# Rounds cleaned

jornadas_clean = clean_jornadas (jornadas)
jornadas_clean
# Out:
# ["'Jornada 1', '15-10-2022'",
#  "'Jornada 2', '22-10-2022'",
#  "'Jornada 3', '29-10-2022'",
#  "'Jornada 4', '05-11-2022'",
#  "'Jornada 5', '12-11-2022'",
#  "'Jornada 6', '19-11-2022'",
#  "'Jornada 7', '26-11-2022'",
#  "'Jornada 8', '03-12-2022'",
#  "'Jornada 9', '17-12-2022'",
#  "'Jornada 10', '14-01-2023'",
#  "'Jornada 11', '21-01-2023'",
#  "'Jornada 12', '04-02-2023'",
#  "'Jornada 13', '11-02-2023'",
#  "'Jornada 14', '25-02-2023'",
#  "'Jornada 15', '04-03-2023'",
#  "'Jornada 16', '11-03-2023'",
#  "'Jornada 17', '18-03-2023'",
#  "'Jornada 18', '25-03-2023'",
#  "'Jornada 19', '01-04-2023'",
#  "'Jornada 20', '15-04-2023'",
#  "'Jornada 21', '22-04-2023'",
#  "'Jornada 22', '29-04-2023'",
#  "'Jornada 23', '06-05-2023'",
#  "'Jornada 24', '13-05-2023'",
#  "'Jornada 25', '20-05-2023'",
#  "'Jornada 26', '27-05-2023'"]

# %%
# Creating a dictionary to joing Results and Rounds



output_dict = {
    "jornada": jornadas_clean,
    "results": results_clean
}
output_dict
# Out:
# {'jornada': ["'Jornada 1', '15-10-2022'",
#   "'Jornada 2', '22-10-2022'",
#   "'Jornada 3', '29-10-2022'",
#   "'Jornada 4', '05-11-2022'",
#   "'Jornada 5', '12-11-2022'",
#   "'Jornada 6', '19-11-2022'",
#   "'Jornada 7', '26-11-2022'",
#   "'Jornada 8', '03-12-2022'",
#   "'Jornada 9', '17-12-2022'",
#   "'Jornada 10', '14-01-2023'",
#   "'Jornada 11', '21-01-2023'",
#   "'Jornada 12', '04-02-2023'",
#   "'Jornada 13', '11-02-2023'",
#   "'Jornada 14', '25-02-2023'",
#   "'Jornada 15', '04-03-2023'",
#   "'Jornada 16', '11-03-2023'",
#   "'Jornada 17', '18-03-2023'",
#   "'Jornada 18', '25-03-2023'",
#   "'Jornada 19', '01-04-2023'",
#   "'Jornada 20', '15-04-2023'",
#   "'Jornada 21', '22-04-2023'",
#   "'Jornada 22', '29-04-2023'",
#   "'Jornada 23', '06-05-2023'",
#   "'Jornada 24', '13-05-2023'",
#   "'Jornada 25', '20-05-2023'",
#   "'Jornada 26', '27-05-2023'"],
#  'results': ['SD ESPANYOL B 0 - 5 C.E.DMS  A',
#   'FUNDACIÓ FUTBOL BADALONA A 4 - 8 SD ESPANYOL B',
#   'SD ESPANYOL B 1 - 1 AELIS-SAGE PARTNER EIXAMPLE B',
#   'FUTSAL CLASSIC BARCELONA, CLUB ESPORTIU  A 3 - 5 SD ESPANYOL B',
#   'SD ESPANYOL B 7 - 3 SANT ANDREU SAGRERA - AESA A',
#   'PLAY FUTSAL A 6 - 4 SD ESPANYOL B',
#   'SD ESPANYOL B 5 - 6 ALZINA ASSOC. ESP. A',
#   'MONTSENY CECD A 2 - 5 SD ESPANYOL B',
#   'SD ESPANYOL B 0 - 3 MAGIC SANTS FUTSAL B',
#   'F.S  BOSCO ROCAFORT A 7 - 4 SD ESPANYOL B',
#   'SD ESPANYOL B 0 - 4 FUTSAL ROSARIO CENTRAL A',
#   'BADALONA FUTSAL IRIS A 5 - 2 SD ESPANYOL B',
#   'LES CORTS ESPORTIU FUTSAL B 2 - 6 SD ESPANYOL B',
#   'C.E.DMS  A 6 - 6 SD ESPANYOL B',
#   'SD ESPANYOL B 4 - 3 FUNDACIÓ FUTBOL BADALONA A',
#   'AELIS-SAGE PARTNER EIXAMPLE B 4 - 6 SD ESPANYOL B',
#   'SD ESPANYOL B 9 - 3 FUTSAL CLASSIC BARCELONA, CLUB ESPORTIU  A',
#   'SANT ANDREU SAGRERA - AESA A 5 - 3 SD ESPANYOL B',
#   'SD ESPANYOL B 7 - 7 PLAY FUTSAL A',
#   'ALZINA ASSOC. ESP. A 7 - 5 SD ESPANYOL B',
#   'SD ESPANYOL B 9 - 5 MONTSENY CECD A',
#   'MAGIC SANTS FUTSAL B 3 - 5 SD ESPANYOL B',
#   'SD ESPANYOL B 3 - 4 F.S  BOSCO ROCAFORT A',
#   'FUTSAL ROSARIO CENTRAL A 1 - 3 SD ESPANYOL B',
#   'SD ESPANYOL B 4 - 7 BADALONA FUTSAL IRIS A',
#   'SD ESPANYOL B 2 - 1 LES CORTS ESPORTIU FUTSAL B']}

# %%
# DATA FRAME

df = pd.DataFrame(output_dict) # keys: name of the column, values: rows
df
# Out:
#                        jornada  \
# 0    'Jornada 1', '15-10-2022'
# 1    'Jornada 2', '22-10-2022'
# 2    'Jornada 3', '29-10-2022'
# 3    'Jornada 4', '05-11-2022'
# 4    'Jornada 5', '12-11-2022'
# 5    'Jornada 6', '19-11-2022'
# 6    'Jornada 7', '26-11-2022'
# 7    'Jornada 8', '03-12-2022'
# 8    'Jornada 9', '17-12-2022'
# 9   'Jornada 10', '14-01-2023'
# 10  'Jornada 11', '21-01-2023'
# 11  'Jornada 12', '04-02-2023'
# 12  'Jornada 13', '11-02-2023'
# 13  'Jornada 14', '25-02-2023'
# 14  'Jornada 15', '04-03-2023'
# 15  'Jornada 16', '11-03-2023'
# 16  'Jornada 17', '18-03-2023'
# 17  'Jornada 18', '25-03-2023'
# 18  'Jornada 19', '01-04-2023'
# 19  'Jornada 20', '15-04-2023'
# 20  'Jornada 21', '22-04-2023'
# 21  'Jornada 22', '29-04-2023'
# 22  'Jornada 23', '06-05-2023'
# 23  'Jornada 24', '13-05-2023'
# 24  'Jornada 25', '20-05-2023'
# 25  'Jornada 26', '27-05-2023'
#
#                                               results
# 0                      SD ESPANYOL B 0 - 5 C.E.DMS  A
# 1      FUNDACIÓ FUTBOL BADALONA A 4 - 8 SD ESPANYOL B
# 2   SD ESPANYOL B 1 - 1 AELIS-SAGE PARTNER EIXAMPLE B
# 3   FUTSAL CLASSIC BARCELONA, CLUB ESPORTIU  A 3 -...
# 4    SD ESPANYOL B 7 - 3 SANT ANDREU SAGRERA - AESA A
# 5                   PLAY FUTSAL A 6 - 4 SD ESPANYOL B
# 6            SD ESPANYOL B 5 - 6 ALZINA ASSOC. ESP. A
# 7                 MONTSENY CECD A 2 - 5 SD ESPANYOL B
# 8            SD ESPANYOL B 0 - 3 MAGIC SANTS FUTSAL B
# 9           F.S  BOSCO ROCAFORT A 7 - 4 SD ESPANYOL B
# 10       SD ESPANYOL B 0 - 4 FUTSAL ROSARIO CENTRAL A
# 11         BADALONA FUTSAL IRIS A 5 - 2 SD ESPANYOL B
# 12    LES CORTS ESPORTIU FUTSAL B 2 - 6 SD ESPANYOL B
# 13                     C.E.DMS  A 6 - 6 SD ESPANYOL B
# 14     SD ESPANYOL B 4 - 3 FUNDACIÓ FUTBOL BADALONA A
# 15  AELIS-SAGE PARTNER EIXAMPLE B 4 - 6 SD ESPANYOL B
# 16  SD ESPANYOL B 9 - 3 FUTSAL CLASSIC BARCELONA, ...
# 17   SANT ANDREU SAGRERA - AESA A 5 - 3 SD ESPANYOL B
# 18                  SD ESPANYOL B 7 - 7 PLAY FUTSAL A
# 19           ALZINA ASSOC. ESP. A 7 - 5 SD ESPANYOL B
# 20                SD ESPANYOL B 9 - 5 MONTSENY CECD A
# 21           MAGIC SANTS FUTSAL B 3 - 5 SD ESPANYOL B
# 22          SD ESPANYOL B 3 - 4 F.S  BOSCO ROCAFORT A
# 23       FUTSAL ROSARIO CENTRAL A 1 - 3 SD ESPANYOL B
# 24         SD ESPANYOL B 4 - 7 BADALONA FUTSAL IRIS A
# 25    SD ESPANYOL B 2 - 1 LES CORTS ESPORTIU FUTSAL B

# %%
# save the dirty df

def save_dataframe_to_csv(df, file_path, index=False):
    df.to_csv(file_path, index=index)

# Call the function to save the DataFrame to a CSV file
save_dataframe_to_csv(df,'../DATA/federacio_sucio.csv', index=False)

# %%
# open the dirty df

# %%
def read_and_display_csv(file_path):
    df = pd.read_csv(file_path)
    return df

file_path = "../DATA/federacio_sucio.csv"
df = read_and_display_csv(file_path)
df
# Out:
#                        jornada  \
# 0    'Jornada 1', '15-10-2022'
# 1    'Jornada 2', '22-10-2022'
# 2    'Jornada 3', '29-10-2022'
# 3    'Jornada 4', '05-11-2022'
# 4    'Jornada 5', '12-11-2022'
# 5    'Jornada 6', '19-11-2022'
# 6    'Jornada 7', '26-11-2022'
# 7    'Jornada 8', '03-12-2022'
# 8    'Jornada 9', '17-12-2022'
# 9   'Jornada 10', '14-01-2023'
# 10  'Jornada 11', '21-01-2023'
# 11  'Jornada 12', '04-02-2023'
# 12  'Jornada 13', '11-02-2023'
# 13  'Jornada 14', '25-02-2023'
# 14  'Jornada 15', '04-03-2023'
# 15  'Jornada 16', '11-03-2023'
# 16  'Jornada 17', '18-03-2023'
# 17  'Jornada 18', '25-03-2023'
# 18  'Jornada 19', '01-04-2023'
# 19  'Jornada 20', '15-04-2023'
# 20  'Jornada 21', '22-04-2023'
# 21  'Jornada 22', '29-04-2023'
# 22  'Jornada 23', '06-05-2023'
# 23  'Jornada 24', '13-05-2023'
# 24  'Jornada 25', '20-05-2023'
# 25  'Jornada 26', '27-05-2023'
#
#                                               results
# 0                      SD ESPANYOL B 0 - 5 C.E.DMS  A
# 1      FUNDACIÓ FUTBOL BADALONA A 4 - 8 SD ESPANYOL B
# 2   SD ESPANYOL B 1 - 1 AELIS-SAGE PARTNER EIXAMPLE B
# 3   FUTSAL CLASSIC BARCELONA, CLUB ESPORTIU  A 3 -...
# 4    SD ESPANYOL B 7 - 3 SANT ANDREU SAGRERA - AESA A
# 5                   PLAY FUTSAL A 6 - 4 SD ESPANYOL B
# 6            SD ESPANYOL B 5 - 6 ALZINA ASSOC. ESP. A
# 7                 MONTSENY CECD A 2 - 5 SD ESPANYOL B
# 8            SD ESPANYOL B 0 - 3 MAGIC SANTS FUTSAL B
# 9           F.S  BOSCO ROCAFORT A 7 - 4 SD ESPANYOL B
# 10       SD ESPANYOL B 0 - 4 FUTSAL ROSARIO CENTRAL A
# 11         BADALONA FUTSAL IRIS A 5 - 2 SD ESPANYOL B
# 12    LES CORTS ESPORTIU FUTSAL B 2 - 6 SD ESPANYOL B
# 13                     C.E.DMS  A 6 - 6 SD ESPANYOL B
# 14     SD ESPANYOL B 4 - 3 FUNDACIÓ FUTBOL BADALONA A
# 15  AELIS-SAGE PARTNER EIXAMPLE B 4 - 6 SD ESPANYOL B
# 16  SD ESPANYOL B 9 - 3 FUTSAL CLASSIC BARCELONA, ...
# 17   SANT ANDREU SAGRERA - AESA A 5 - 3 SD ESPANYOL B
# 18                  SD ESPANYOL B 7 - 7 PLAY FUTSAL A
# 19           ALZINA ASSOC. ESP. A 7 - 5 SD ESPANYOL B
# 20                SD ESPANYOL B 9 - 5 MONTSENY CECD A
# 21           MAGIC SANTS FUTSAL B 3 - 5 SD ESPANYOL B
# 22          SD ESPANYOL B 3 - 4 F.S  BOSCO ROCAFORT A
# 23       FUTSAL ROSARIO CENTRAL A 1 - 3 SD ESPANYOL B
# 24         SD ESPANYOL B 4 - 7 BADALONA FUTSAL IRIS A
# 25    SD ESPANYOL B 2 - 1 LES CORTS ESPORTIU FUTSAL B

# %%
# Function to clean DATAFRAME

def cleaning_df (df):

    df['jornada'] = df['jornada'].str.replace("'", '')
    df['jornada_date'] = df['jornada'].str.extract(r'(\d{2}-\d{2}-\d{4})')
    df['jornada'] = df['jornada'].str.split(',').str[0]
    df['date'] = pd.to_datetime(df['jornada_date'], format='%d-%m-%Y').dt.strftime('%Y/%m/%d')

    return df

# %%
df = cleaning_df (df)
df
# Out:
#        jornada                                            results  \
# 0    Jornada 1                     SD ESPANYOL B 0 - 5 C.E.DMS  A
# 1    Jornada 2     FUNDACIÓ FUTBOL BADALONA A 4 - 8 SD ESPANYOL B
# 2    Jornada 3  SD ESPANYOL B 1 - 1 AELIS-SAGE PARTNER EIXAMPLE B
# 3    Jornada 4  FUTSAL CLASSIC BARCELONA, CLUB ESPORTIU  A 3 -...
# 4    Jornada 5   SD ESPANYOL B 7 - 3 SANT ANDREU SAGRERA - AESA A
# 5    Jornada 6                  PLAY FUTSAL A 6 - 4 SD ESPANYOL B
# 6    Jornada 7           SD ESPANYOL B 5 - 6 ALZINA ASSOC. ESP. A
# 7    Jornada 8                MONTSENY CECD A 2 - 5 SD ESPANYOL B
# 8    Jornada 9           SD ESPANYOL B 0 - 3 MAGIC SANTS FUTSAL B
# 9   Jornada 10          F.S  BOSCO ROCAFORT A 7 - 4 SD ESPANYOL B
# 10  Jornada 11       SD ESPANYOL B 0 - 4 FUTSAL ROSARIO CENTRAL A
# 11  Jornada 12         BADALONA FUTSAL IRIS A 5 - 2 SD ESPANYOL B
# 12  Jornada 13    LES CORTS ESPORTIU FUTSAL B 2 - 6 SD ESPANYOL B
# 13  Jornada 14                     C.E.DMS  A 6 - 6 SD ESPANYOL B
# 14  Jornada 15     SD ESPANYOL B 4 - 3 FUNDACIÓ FUTBOL BADALONA A
# 15  Jornada 16  AELIS-SAGE PARTNER EIXAMPLE B 4 - 6 SD ESPANYOL B
# 16  Jornada 17  SD ESPANYOL B 9 - 3 FUTSAL CLASSIC BARCELONA, ...
# 17  Jornada 18   SANT ANDREU SAGRERA - AESA A 5 - 3 SD ESPANYOL B
# 18  Jornada 19                  SD ESPANYOL B 7 - 7 PLAY FUTSAL A
# 19  Jornada 20           ALZINA ASSOC. ESP. A 7 - 5 SD ESPANYOL B
# 20  Jornada 21                SD ESPANYOL B 9 - 5 MONTSENY CECD A
# 21  Jornada 22           MAGIC SANTS FUTSAL B 3 - 5 SD ESPANYOL B
# 22  Jornada 23          SD ESPANYOL B 3 - 4 F.S  BOSCO ROCAFORT A
# 23  Jornada 24       FUTSAL ROSARIO CENTRAL A 1 - 3 SD ESPANYOL B
# 24  Jornada 25         SD ESPANYOL B 4 - 7 BADALONA FUTSAL IRIS A
# 25  Jornada 26    SD ESPANYOL B 2 - 1 LES CORTS ESPORTIU FUTSAL B
#
#    jornada_date        date
# 0    15-10-2022  2022/10/15
# 1    22-10-2022  2022/10/22
# 2    29-10-2022  2022/10/29
# 3    05-11-2022  2022/11/05
# 4    12-11-2022  2022/11/12
# 5    19-11-2022  2022/11/19
# 6    26-11-2022  2022/11/26
# 7    03-12-2022  2022/12/03
# 8    17-12-2022  2022/12/17
# 9    14-01-2023  2023/01/14
# 10   21-01-2023  2023/01/21
# 11   04-02-2023  2023/02/04
# 12   11-02-2023  2023/02/11
# 13   25-02-2023  2023/02/25
# 14   04-03-2023  2023/03/04
# 15   11-03-2023  2023/03/11
# 16   18-03-2023  2023/03/18
# 17   25-03-2023  2023/03/25
# 18   01-04-2023  2023/04/01
# 19   15-04-2023  2023/04/15
# 20   22-04-2023  2023/04/22
# 21   29-04-2023  2023/04/29
# 22   06-05-2023  2023/05/06
# 23   13-05-2023  2023/05/13
# 24   20-05-2023  2023/05/20
# 25   27-05-2023  2023/05/27

# %%
# Adding win/draw/lost
def add_column (df):
    wdl_values = ['L', 'W', 'D', 'W', 'W', 'L', 'L', 'W', 'L', 'L', 'L', 'L', 'W', 'D', 'W', 'W', 'W', 'L', 'D', 'L', 'W', 'W', 'L', 'W', 'L', 'W']
    df['W/D/L'] = wdl_values

# %%
#adding column
add_column(df)
df
# Out:
#        jornada                                            results  \
# 0    Jornada 1                     SD ESPANYOL B 0 - 5 C.E.DMS  A
# 1    Jornada 2     FUNDACIÓ FUTBOL BADALONA A 4 - 8 SD ESPANYOL B
# 2    Jornada 3  SD ESPANYOL B 1 - 1 AELIS-SAGE PARTNER EIXAMPLE B
# 3    Jornada 4  FUTSAL CLASSIC BARCELONA, CLUB ESPORTIU  A 3 -...
# 4    Jornada 5   SD ESPANYOL B 7 - 3 SANT ANDREU SAGRERA - AESA A
# 5    Jornada 6                  PLAY FUTSAL A 6 - 4 SD ESPANYOL B
# 6    Jornada 7           SD ESPANYOL B 5 - 6 ALZINA ASSOC. ESP. A
# 7    Jornada 8                MONTSENY CECD A 2 - 5 SD ESPANYOL B
# 8    Jornada 9           SD ESPANYOL B 0 - 3 MAGIC SANTS FUTSAL B
# 9   Jornada 10          F.S  BOSCO ROCAFORT A 7 - 4 SD ESPANYOL B
# 10  Jornada 11       SD ESPANYOL B 0 - 4 FUTSAL ROSARIO CENTRAL A
# 11  Jornada 12         BADALONA FUTSAL IRIS A 5 - 2 SD ESPANYOL B
# 12  Jornada 13    LES CORTS ESPORTIU FUTSAL B 2 - 6 SD ESPANYOL B
# 13  Jornada 14                     C.E.DMS  A 6 - 6 SD ESPANYOL B
# 14  Jornada 15     SD ESPANYOL B 4 - 3 FUNDACIÓ FUTBOL BADALONA A
# 15  Jornada 16  AELIS-SAGE PARTNER EIXAMPLE B 4 - 6 SD ESPANYOL B
# 16  Jornada 17  SD ESPANYOL B 9 - 3 FUTSAL CLASSIC BARCELONA, ...
# 17  Jornada 18   SANT ANDREU SAGRERA - AESA A 5 - 3 SD ESPANYOL B
# 18  Jornada 19                  SD ESPANYOL B 7 - 7 PLAY FUTSAL A
# 19  Jornada 20           ALZINA ASSOC. ESP. A 7 - 5 SD ESPANYOL B
# 20  Jornada 21                SD ESPANYOL B 9 - 5 MONTSENY CECD A
# 21  Jornada 22           MAGIC SANTS FUTSAL B 3 - 5 SD ESPANYOL B
# 22  Jornada 23          SD ESPANYOL B 3 - 4 F.S  BOSCO ROCAFORT A
# 23  Jornada 24       FUTSAL ROSARIO CENTRAL A 1 - 3 SD ESPANYOL B
# 24  Jornada 25         SD ESPANYOL B 4 - 7 BADALONA FUTSAL IRIS A
# 25  Jornada 26    SD ESPANYOL B 2 - 1 LES CORTS ESPORTIU FUTSAL B
#
#    jornada_date        date W/D/L
# 0    15-10-2022  2022/10/15     L
# 1    22-10-2022  2022/10/22     W
# 2    29-10-2022  2022/10/29     D
# 3    05-11-2022  2022/11/05     W
# 4    12-11-2022  2022/11/12     W
# 5    19-11-2022  2022/11/19     L
# 6    26-11-2022  2022/11/26     L
# 7    03-12-2022  2022/12/03     W
# 8    17-12-2022  2022/12/17     L
# 9    14-01-2023  2023/01/14     L
# 10   21-01-2023  2023/01/21     L
# 11   04-02-2023  2023/02/04     L
# 12   11-02-2023  2023/02/11     W
# 13   25-02-2023  2023/02/25     D
# 14   04-03-2023  2023/03/04     W
# 15   11-03-2023  2023/03/11     W
# 16   18-03-2023  2023/03/18     W
# 17   25-03-2023  2023/03/25     L
# 18   01-04-2023  2023/04/01     D
# 19   15-04-2023  2023/04/15     L
# 20   22-04-2023  2023/04/22     W
# 21   29-04-2023  2023/04/29     W
# 22   06-05-2023  2023/05/06     L
# 23   13-05-2023  2023/05/13     W
# 24   20-05-2023  2023/05/20     L
# 25   27-05-2023  2023/05/27     W

# %%
# Function to rename dataframe columns

def rename_columns(df):
    df = df.rename(columns={'jornada': 'ROUND', 'results': 'RESULTS'})
    df = df.drop('jornada_date', axis=1)
    df = df.rename(columns={'date': 'DATE'})
    return df

# %%
# Renamed columns

df = rename_columns(df)
df
# Out:
#          ROUND                                            RESULTS        DATE  \
# 0    Jornada 1                     SD ESPANYOL B 0 - 5 C.E.DMS  A  2022/10/15
# 1    Jornada 2     FUNDACIÓ FUTBOL BADALONA A 4 - 8 SD ESPANYOL B  2022/10/22
# 2    Jornada 3  SD ESPANYOL B 1 - 1 AELIS-SAGE PARTNER EIXAMPLE B  2022/10/29
# 3    Jornada 4  FUTSAL CLASSIC BARCELONA, CLUB ESPORTIU  A 3 -...  2022/11/05
# 4    Jornada 5   SD ESPANYOL B 7 - 3 SANT ANDREU SAGRERA - AESA A  2022/11/12
# 5    Jornada 6                  PLAY FUTSAL A 6 - 4 SD ESPANYOL B  2022/11/19
# 6    Jornada 7           SD ESPANYOL B 5 - 6 ALZINA ASSOC. ESP. A  2022/11/26
# 7    Jornada 8                MONTSENY CECD A 2 - 5 SD ESPANYOL B  2022/12/03
# 8    Jornada 9           SD ESPANYOL B 0 - 3 MAGIC SANTS FUTSAL B  2022/12/17
# 9   Jornada 10          F.S  BOSCO ROCAFORT A 7 - 4 SD ESPANYOL B  2023/01/14
# 10  Jornada 11       SD ESPANYOL B 0 - 4 FUTSAL ROSARIO CENTRAL A  2023/01/21
# 11  Jornada 12         BADALONA FUTSAL IRIS A 5 - 2 SD ESPANYOL B  2023/02/04
# 12  Jornada 13    LES CORTS ESPORTIU FUTSAL B 2 - 6 SD ESPANYOL B  2023/02/11
# 13  Jornada 14                     C.E.DMS  A 6 - 6 SD ESPANYOL B  2023/02/25
# 14  Jornada 15     SD ESPANYOL B 4 - 3 FUNDACIÓ FUTBOL BADALONA A  2023/03/04
# 15  Jornada 16  AELIS-SAGE PARTNER EIXAMPLE B 4 - 6 SD ESPANYOL B  2023/03/11
# 16  Jornada 17  SD ESPANYOL B 9 - 3 FUTSAL CLASSIC BARCELONA, ...  2023/03/18
# 17  Jornada 18   SANT ANDREU SAGRERA - AESA A 5 - 3 SD ESPANYOL B  2023/03/25
# 18  Jornada 19                  SD ESPANYOL B 7 - 7 PLAY FUTSAL A  2023/04/01
# 19  Jornada 20           ALZINA ASSOC. ESP. A 7 - 5 SD ESPANYOL B  2023/04/15
# 20  Jornada 21                SD ESPANYOL B 9 - 5 MONTSENY CECD A  2023/04/22
# 21  Jornada 22           MAGIC SANTS FUTSAL B 3 - 5 SD ESPANYOL B  2023/04/29
# 22  Jornada 23          SD ESPANYOL B 3 - 4 F.S  BOSCO ROCAFORT A  2023/05/06
# 23  Jornada 24       FUTSAL ROSARIO CENTRAL A 1 - 3 SD ESPANYOL B  2023/05/13
# 24  Jornada 25         SD ESPANYOL B 4 - 7 BADALONA FUTSAL IRIS A  2023/05/20
# 25  Jornada 26    SD ESPANYOL B 2 - 1 LES CORTS ESPORTIU FUTSAL B  2023/05/27
#
#    W/D/L
# 0      L
# 1      W
# 2      D
# 3      W
# 4      W
# 5      L
# 6      L
# 7      W
# 8      L
# 9      L
# 10     L
# 11     L
# 12     W
# 13     D
# 14     W
# 15     W
# 16     W
# 17     L
# 18     D
# 19     L
# 20     W
# 21     W
# 22     L
# 23     W
# 24     L
# 25     W

# %%
def save_dataframe_to_csv(df, file_path, index=False):
    df.to_csv(file_path, index=index)

# Call the function to save the DataFrame to a CSV file
save_dataframe_to_csv(df, '../DATA/df_federacio.csv', index=False)
